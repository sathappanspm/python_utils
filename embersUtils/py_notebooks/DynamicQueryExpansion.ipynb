# %%
cd /home/vicky/AUR
# Out:
# /home/vicky/AUR

# %%
#cd /home/vicky/AUR
import json
import os
import boto

#print os.environ.keys()
key="AKIAJZ2N4UOI4TP4YBRQ"
secret = "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"
#key = os.environ["AWS_ACCESS_KEY_ID"]
#secrete = os.environ["AWS_SECRET_ACCESS_KEY"]
conn = boto.connect_sdb(key, secret)
dom = conn.lookup("warnings")

if dom is None:
    dom = conn.create_domain("warnings")

stmt = "SELECT * FROM warnings WHERE model like 'mle%'"

dynwarnings = dom.select(stmt)
derived = []
eids = []
cnt = 0
for k in dynwarnings:
    if isinstance(k["derivedFrom"], basestring):
        k["derivedFrom"] = eval(k["derivedFrom"])
    if k["date"] > "2013-06-14":
        cnt += 1
        #print k["date"], k["model"]
        derived.append(k["derivedFrom"]["derivedIds"])
        eids.append(k["embersId"])
print cnt
#print derived
#print eids
# Out:
# 15

# %%
from gutils import normalize_str
OSI_FORMAT_LOC_CORRECT = {'Mexico,Distrito Federal,Ciudad De Mexico': 'Mexico,Ciudad de MÃ©xico,Ciudad de MÃ©xico',
                          'Argentina,Distrito Federal,Buenos Aires': 'Argentina,,Buenos Aires',
                          'Venezuela,Distrito Capital,Caracas': 'Venezuela,Caracas,Caracas',
                          'Colombia,Bogota,Bogota': 'Colombia,Bogota,Bogota',
                          'Ecuador,Pichincha,Quito': 'Ecuador,Pichincha,Quito',
                          'El Salvador, San Salvador, San Salvador': 'El Salvador, San Salvador, San Salvador',
                          'Paraguay,Asuncion,Asuncion': 'Paraguay,Asuncion,Asuncion',
                          'Uruguay,Montevideo,Montevideo': 'Uruguay,Montevideo,Montevideo',
                          'Hoduras,Tegucigalpa,Tegucigalpa': 'Hoduras,Tegucigalpa,Tegucigalpa',
                          'Peru,Lima,Lima': 'Peru,Lima,Lima',
                          'Brazil,Brasilia,Brasilia': 'Brazil,Brasilia,Brasilia',
                          'Chile,Metropolitana,Santiago': 'Chile,Santiago,Santiago'
                          }


OSI_FORMAT_ST_CORR = dict()
for k in OSI_FORMAT_LOC_CORRECT:
    OSI_FORMAT_ST_CORR[",".join(k.split(",")[:2])] = ",".join(OSI_FORMAT_LOC_CORRECT[k].split(",")[:2])
OSI_FORMAT_ST_REVERSE = {v: k for k, v in OSI_FORMAT_ST_CORR.items()}

#print OSI_FORMAT_ST_REVERSE
def toState(co, st, ci):
    locstr = ",".join([normalize_str(co).title(), normalize_str(st).title(), normalize_str(ci).title()])
    if locstr in OSI_FORMAT_LOC_CORRECT:
        return OSI_FORMAT_LOC_CORRECT[locstr].split(",")[:2]
    if (not ci) or ci == "-":
        locstr = ",".join([normalize_str(co).title(), normalize_str(st).title()])
        if locstr in OSI_FORMAT_ST_REVERSE:
            return OSI_FORMAT_ST_REVERSE[locstr].split(",")
    return co, st

s = OSI_FORMAT_LOC_CORRECT.keys()
toState("Chile", "santiago", "posada")
# Out:
# ('Chile', 'santiago')

# %%
import pickle
pkl = open("/home/vicky/co_st_ci.pkl")
p = pickle.load(pkl)

# %%
len(p)
p[1]
#from embers.geocode import geo
OSI_FORMAT_LOC_CORRECT = {'Mexico,Distrito Federal,Ciudad De Mexico': 'Mexico,Ciudad de México,Ciudad de México',
                          'Argentina,Distrito Federal,Buenos Aires': 'Argentina,,Buenos Aires',
                          'Venezuela,Distrito Capital,Caracas': 'Venezuela,Caracas,Caracas',
                          'Colombia,Bogota,Bogota': 'Colombia,Bogota,Bogota',
                          'Ecuador,Pichincha,Quito': 'Ecuador,Pichincha,Quito',
                          'El Salvador, San Salvador, San Salvador': 'El Salvador, San Salvador, San Salvador',
                          'Paraguay,Asuncion,Asuncion': 'Paraguay,Asuncion,Asuncion',
                          'Uruguay,Montevideo,Montevideo': 'Uruguay,Montevideo,Montevideo',
                          'Hoduras,Tegucigalpa,Tegucigalpa': 'Hoduras,Tegucigalpa,Tegucigalpa',
                          'Peru,Lima,Lima': 'Peru,Lima,Lima',
                          'Brazil,Brasilia,Brasilia': 'Brazil,Brasilia,Brasilia',
                          'Chile,Metropolitana,Santiago': 'Chile,Santiago,Santiago'
                          }

OSI_FORMAT_ST_CORR = dict()
for k in OSI_FORMAT_LOC_CORRECT:
    OSI_FORMAT_ST_CORR[",".join(k.split(",")[:2])] = ",".join(OSI_FORMAT_LOC_CORRECT[k].split(",")[:2])

OSI_FORMAT_LOC_REVERSE = {v: k for k, v in OSI_FORMAT_LOC_CORRECT.items()}
OSI_FORMAT_ST_REVERSE = {v: k for k, v in OSI_FORMAT_ST_CORR.items()}
def toState(co, st, ci):
    locstr = ",".join([normalize_str(co).title(), normalize_str(st).title(), normalize_str(ci).title()])
    if locstr in OSI_FORMAT_LOC_REVERSE:
        return OSI_FORMAT_LOC_REVERSE[locstr].split(",")[:2]
    if (not ci) or ci == "-":
        locstr = ",".join([normalize_str(co).title(), normalize_str(st).title()])
        if locstr in OSI_FORMAT_ST_REVERSE:
            return OSI_FORMAT_ST_REVERSE[locstr].split(",")
    return co, st

# %%
s = []
for k in p:
    s.append(toState(k[0], k[1], k[2]))
len(s)
s[3]

import re
strRe = re.compile("[a-zA-Z]+")

for k in p:
    for s in k:
        if not strRe.match(s):
            print s.decode("utf-8")
# Out:
# 10 de abril
# Ñeembucú
# 31 de octubre
# 9 de julio
# Águas de chapecó
# Álvaro obregón
# Ñeembucú
# Água nova
# Álvarez
# Água fria
# 20 de noviembre
# Álvares machado
# Ñacunday
# 20 de noviembre
# Ángel albino corzo
# 9 de julio
# Água azul do norte
# Águas da prata
# Água limpa
# Águas vermelhas
# Álvaro obregón
# 6 de junio
# 2da. sección de medio monte
# 30 de agosto
# 16 de septiembre
# Água boa
# Água branca
# 25 de mayo
# 18 de agosto
# Ñeembucú
# 12 de octubre
# Água branca
# 1ro. de mayo
# Ñeembucú
# Álvaro obregón
# 19 de febrero de 1812
# Ñanducita
# Árbol grande
# Ângulo
# Álvaro de carvalho
# Águas de são pedro
# 25 de mayo
# Ñeembucú
# Águas belas
# Álvaro obregón
# Ñahuimpuquio
# Água doce do norte
# Ánimas trujano
# Óleo
# 28 de noviembre
# Áurea
# Ñeembucú
# Ñeembucú
# Álvaro obregón
# Álvaro obregón
# 17 de agosto
# Águas de lindóia
# Ñilhue
# Úrsulo galván
# Ñeembucú
# Ñeembucú
# Ñeembucú
# 16 de julio
# 25 de mayo
# Águia branca
# Álvaro obregón
# Ñeembucú
# ...
