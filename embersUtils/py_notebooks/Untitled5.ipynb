# %%
a = open("mitreIds.txt")
mids = {k.split()[0].strip(): k.split()[1] for k in a}

# %%
import boto
#print os.environ.keys()
key="AKIAJZ2N4UOI4TP4YBRQ"
secret = "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"
#key = os.environ["AWS_ACCESS_KEY_ID"]
#secrete = os.environ["AWS_SECRET_ACCESS_KEY"]
conn = boto.connect_sdb(key, secret)
dom = conn.lookup("warnings")

if dom is None:
    dom = conn.create_domain("warnings")
    
stmt = "SELECT * FROM warnings WHERE eventType like '01%'"
dynwarnings = dom.select(stmt)
plwrngs = []
for k in dynwarnings:
    if isinstance(k["derivedFrom"], basestring):
        k["derivedFrom"] = eval(k["derivedFrom"])
    if "planned" in k["model"].lower():
        plwrngs.append(k)

# %%
len(plwrngs)
dl = {}
dmap = {}
plids = {k["embersId"]: k for k in plwrngs}
for k in plwrngs:
    if not "mitreId" in k:
        continue
        
    if k["embersId"] in mids:
        #dmap.setdefault(k["eventDate"][:7], 0)
        #dmap[k["eventDate"][:7]] += 1
        if "state" in k:
            dl[k["embersId"]] = k["state"]
        else:
            dl[k["embersId"]] = k["delivered"]
        #dl.append[k["delivered"] if "delivered" in k else k["state"]]

# %%
print len(dl)
plmids = set([k for k in plids if k in mids])
len(plmids)
# Out:
# 1021
# 1021

# %%
for k in dl:
    print dl[k]
# Out:
# 2013-05-08T14:30:08.211234
# 2013-05-08T14:30:08.211234
# DELIVERED 2013-06-25T23:30:05.850565
# 2013-05-08T14:30:08.211234
# 2013-05-08T14:30:08.211234
# 2013-05-08T14:30:08.211234
# 2013-05-08T14:30:08.211234
# 2013-05-05T19:30:03.445953
# 2013-05-10T19:30:03.552675
# 2013-05-08T14:30:08.211234
# 2013-04-23T14:30:06.037621
# 2013-06-05T19:30:03.462850
# 2013-05-05T14:30:05.602460
# 2013-05-01T23:30:04.377534
# 2013-05-01T23:30:04.377534
# 2013-05-01T23:30:04.377534
# 2013-05-01T19:30:05.735457
# 2013-05-13T14:30:06.237390
# 2013-05-01T19:30:05.735457
# DELIVERED 2013-07-03T23:30:02.070927
# DELIVERED 2013-07-03T19:30:04.277443
# 2013-04-24T19:30:05.500679
# DELIVERED 2013-07-03T23:30:02.285427
# 2013-04-24T19:30:05.500679
# 2013-05-01T03:30:05.699626
# 2013-04-24T19:30:05.500679
# 2013-04-24T19:30:05.500679
# 2013-05-01T23:30:04.377534
# 2013-05-05T19:30:03.445953
# 2013-05-07T14:30:06.436775
# 2013-05-07T14:30:06.436775
# 2013-05-07T14:30:06.436775
# 2013-05-07T14:30:06.436775
# ...

# %%
a = open("/home/vicky/planned_protest_ids.txt")
nathanslist = {k.split()[0]: k.split()[1] for k in a}
rem = set(dl.keys()) - set(nathanslist.keys())

# %%
out = open("missingPlanned_ProtestIds.txt", "w")
for k in rem:
    out.write("%s\t%s\n" % (k, plids[k]["mitreId"]))

# %%
out.close()

# %%
pwd
# Out:
# u'/home/vicky/DataSets/plannedProtest'
